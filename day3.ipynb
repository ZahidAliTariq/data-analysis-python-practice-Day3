# %%
# for pandas library import
import pandas as pd

# %%
# for read_csv data
df = pd.read_csv("student_performance_data_70.csv")

# %%
# for check read_csv data
df
# Out:
#     ID     Name  Gender Class  Math  Science  English  Total Result  \
# 0    1   Danish  Female   9th    66      100       69    235   Pass
# 1    2   Danish    Male  10th    99       46       58    203   Pass
# 2    3    Mehak    Male  10th    82       32       56    170   Pass
# 3    4     Neha  Female   9th    50       73       32    155   Pass
# 4    5      Ali  Female  10th    32       98       66    196   Pass
# ..  ..      ...     ...   ...   ...      ...      ...    ...    ...
# 65  66    Tania  Female   9th    63       38       41    142   Fail
# 66  67  Zeeshan    Male  10th    59       39       46    144   Fail
# 67  68    Imran  Female  10th    55       92       83    230   Pass
# 68  69   Danish    Male  10th    87       58       98    243   Pass
# 69  70     Adil  Female   9th    34       48       98    180   Pass
#
#          City Registered_Date
# 0      Multan      2024-10-16
# 1      Multan      2024-12-03
# 2     Karachi      2024-08-07
# ...

# %%
# 9th class
df_class9 = df[df["Class"] == "9th"]
average_9th = df_class9["Math"] + df_class9["Science"] + df_class9["English"].mean()

print("Average of 9th class:")
print(df_class9)
# Out:
# Average of 9th class:
#     ID    Name  Gender Class  Math  Science  English  Total Result  \
# 0    1  Danish  Female   9th    66      100       69    235   Pass
# 3    4    Neha  Female   9th    50       73       32    155   Pass
# 7    8  Maliha  Female   9th   100       87       33    220   Pass
# 8    9   Imran    Male   9th    86       43       61    190   Pass
# 9   10     Ali    Male   9th    56       64       79    199   Pass
# 10  11    Zoya  Female   9th    34       32       60    126   Fail
# 15  16     Ali    Male   9th    33       59       91    183   Pass
# 18  19  Ayesha  Female   9th    75       30       71    176   Pass
# 22  23    Rida  Female   9th    95       35       70    200   Pass
# 23  24    Rida    Male   9th    53       43      100    196   Pass
# 24  25   Noman  Female   9th    97       58       60    215   Pass
# 25  26   Noman  Female   9th    66       35       53    154   Pass
# 26  27   Tariq    Male   9th    87       48       60    195   Pass
# ...

# %%
# 10th class
df_class10 = df[df["Class"] == "10th"]
average_10th = df_class10["Math"] + df_class10["Science"] + df_class10["English"].mean()

print("Average of 10th class:")
print(df_class10)
# Out:
# Average of 10th class:
#     ID     Name  Gender Class  Math  Science  English  Total Result  \
# 1    2   Danish    Male  10th    99       46       58    203   Pass
# 2    3    Mehak    Male  10th    82       32       56    170   Pass
# 4    5      Ali  Female  10th    32       98       66    196   Pass
# 5    6    Rehan  Female  10th    68       38       83    189   Pass
# 6    7    Rabia  Female  10th    56       45       82    183   Pass
# 11  12     Rida  Female  10th    54       68       94    216   Pass
# 12  13    Rehan  Female  10th    51       87       45    183   Pass
# 13  14    Laiba    Male  10th    32       57       57    146   Fail
# 14  15    Imran    Male  10th    88       48       78    214   Pass
# 16  17     Neha  Female  10th    71       40       38    149   Fail
# 17  18     Sana    Male  10th    53       54       80    187   Pass
# 19  20    Mehak  Female  10th    36       32       67    135   Fail
# ...

# %%
# passed in lahore
df_pass_lahore = df[(df["City"] == "Lahore") & (df["Result"] == "Pass")]
print("Passed in Lahore:")
print(df_pass_lahore)
# Out:
# Passed in Lahore:
#     ID    Name  Gender Class  Math  Science  English  Total Result    City  \
# 5    6   Rehan  Female  10th    68       38       83    189   Pass  Lahore
# 7    8  Maliha  Female   9th   100       87       33    220   Pass  Lahore
# 9   10     Ali    Male   9th    56       64       79    199   Pass  Lahore
# 21  22    Asad    Male  10th    99       91       62    252   Pass  Lahore
# 24  25   Noman  Female   9th    97       58       60    215   Pass  Lahore
# 34  35   Imran    Male   9th    59       77       43    179   Pass  Lahore
# 42  43   Noman  Female   9th    41       98       73    212   Pass  Lahore
# 49  50   Mehak    Male  10th    31       41       89    161   Pass  Lahore
# 57  58  Danish  Female  10th    62       89       36    187   Pass  Lahore
# 59  60   Noman  Female  10th    55       95       97    247   Pass  Lahore
#
#    Registered_Date
# 5       2025-03-07
# 7       2024-05-26
# 9       2025-01-28
# 21      2025-03-28
# 24      2024-06-02
# ...

# %%
# fail students
df_fail_students = df[df["Result"] == "Fail"]
print("Fail students are:")
print(df_fail_students)
# Out:
# Fail students are:
#     ID     Name  Gender Class  Math  Science  English  Total Result  \
# 10  11     Zoya  Female   9th    34       32       60    126   Fail
# 13  14    Laiba    Male  10th    32       57       57    146   Fail
# 16  17     Neha  Female  10th    71       40       38    149   Fail
# 19  20    Mehak  Female  10th    36       32       67    135   Fail
# 41  42     Hina    Male  10th    30       41       31    102   Fail
# 50  51    Bilal  Female   9th    39       47       43    129   Fail
# 51  52    Usman    Male  10th    33       55       38    126   Fail
# 53  54     Neha    Male  10th    31       47       38    116   Fail
# 55  56    Tania    Male  10th    31       34       56    121   Fail
# 56  57    Haris  Female   9th    48       37       49    134   Fail
# 60  61    Kiran  Female   9th    54       51       37    142   Fail
# 65  66    Tania  Female   9th    63       38       41    142   Fail
# ...

# %%
# student list Karachi
df_student_karachi = df[df["City"] == "Karachi"]
print("Student list of Karachi is:")
print(df_student_karachi)
# Out:
# Student list of Karachi is:
#     ID    Name  Gender Class  Math  Science  English  Total Result     City  \
# 2    3   Mehak    Male  10th    82       32       56    170   Pass  Karachi
# 15  16     Ali    Male   9th    33       59       91    183   Pass  Karachi
# 18  19  Ayesha  Female   9th    75       30       71    176   Pass  Karachi
# 20  21  Maliha  Female  10th    90       93       30    213   Pass  Karachi
# 26  27   Tariq    Male   9th    87       48       60    195   Pass  Karachi
# 32  33   Usman    Male   9th    73       53       73    199   Pass  Karachi
# 38  39   Noman  Female   9th    72       95       57    224   Pass  Karachi
# 39  40   Haris    Male  10th    99       75       51    225   Pass  Karachi
# 41  42    Hina    Male  10th    30       41       31    102   Fail  Karachi
# 44  45   Tariq    Male   9th    75       81       68    224   Pass  Karachi
# 46  47   Tariq    Male  10th    91       79       61    231   Pass  Karachi
# ...

# %%
# top 10 students
df_top_students = df[df["Result"] == "Pass"].nlargest(10, ["Math", "Science", "English"])
print("Top 10 Students is:")
print(df_top_students)
# Out:
# Top 10 Students is:
#     ID    Name  Gender Class  Math  Science  English  Total Result  \
# 7    8  Maliha  Female   9th   100       87       33    220   Pass
# 21  22    Asad    Male  10th    99       91       62    252   Pass
# 39  40   Haris    Male  10th    99       75       51    225   Pass
# 33  34    Rida    Male  10th    99       65       56    220   Pass
# 47  48  Ayesha  Female  10th    99       59      100    258   Pass
# 1    2  Danish    Male  10th    99       46       58    203   Pass
# 24  25   Noman  Female   9th    97       58       60    215   Pass
# 30  31    Shan  Female   9th    97       30       78    205   Pass
# 58  59    Shan  Female   9th    96       79       86    261   Pass
# 22  23    Rida  Female   9th    95       35       70    200   Pass
#
#           City Registered_Date
# 7       Lahore      2024-05-26
# 21      Lahore      2025-03-28
# 39     Karachi      2024-06-02
# 33      Multan      2024-05-14
# 47   Islamabad      2025-02-19
# ...
